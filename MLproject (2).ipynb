# %% [markdown]
# https://github.com/statsbomb/open-data dataset

# %%
#Necessary libraries
from mplsoccer import Sbopen
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
parser = Sbopen() #To read JSON files

# %%
competitions = parser.competition()
competitions.head(10)
# Out:
#    competition_id  season_id country_name        competition_name  \
# 0               9        281      Germany           1. Bundesliga
# 1               9         27      Germany           1. Bundesliga
# 2            1267        107       Africa  African Cup of Nations
# 3              16          4       Europe        Champions League
# 4              16          1       Europe        Champions League
# 5              16          2       Europe        Champions League
# 6              16         27       Europe        Champions League
# 7              16         26       Europe        Champions League
# 8              16         25       Europe        Champions League
# 9              16         24       Europe        Champions League
#
#   competition_gender  competition_youth  competition_international  \
# 0               male              False                      False
# 1               male              False                      False
# ...

# %%
df_match = parser.match(competition_id=2, season_id=27) #Season 15/16 premier league
df_match.head()
# Out:
#    match_id match_date            kick_off  home_score  away_score  \
# 0   3754058 2016-01-02 2016-01-02 16:00:00           0           0
# 1   3754245 2015-10-17 2015-10-17 16:00:00           1           0
# 2   3754136 2015-12-19 2015-12-19 18:30:00           1           1
# 3   3754037 2016-04-30 2016-04-30 16:00:00           2           1
# 4   3754039 2016-02-13 2016-02-13 16:00:00           1           2
#
#   match_status match_status_360               last_updated  \
# 0    available       processing 2021-10-29 23:44:19.940296
# 1    available        scheduled 2022-12-01 13:09:17.044015
# 2    available        scheduled 2020-11-12 23:48:19.757269
# 3    available       processing 2021-07-07 17:59:57.456000
# 4    available       processing 2021-07-25 18:09:51.386000
#
#          last_updated_360  match_week  ...  competition_stage_id  \
# 0 2021-06-12 16:17:31.694          20  ...                     1
# 1 2021-06-13 16:17:31.694           9  ...                     1
# ...

# %%
df_match.columns
# Out:
# Index(['match_id', 'match_date', 'kick_off', 'home_score', 'away_score',
#        'match_status', 'match_status_360', 'last_updated', 'last_updated_360',
#        'match_week', 'competition_id', 'country_name', 'competition_name',
#        'season_id', 'season_name', 'home_team_id', 'home_team_name',
#        'home_team_gender', 'home_team_group', 'home_team_country_id',
#        'home_team_country_name', 'home_team_managers_id',
#        'home_team_managers_name', 'home_team_managers_nickname',
#        'home_team_managers_dob', 'home_team_managers_country_id',
#        'home_team_managers_country_name', 'away_team_id', 'away_team_name',
#        'away_team_gender', 'away_team_group', 'away_team_country_id',
#        'away_team_country_name', 'away_team_managers_id',
#        'away_team_managers_name', 'away_team_managers_nickname',
#        'away_team_managers_dob', 'away_team_managers_country_id',
#        'away_team_managers_country_name', 'metadata_data_version',
# ...

# %%
# iterate through all matches to get the events data
df_matches = {}
for i, id in enumerate(df_match['match_id']):
  df_matches[id] = {}
  df_matches[id]['event'], df_matches[id]['related'], df_matches[id]['freeze'], df_matches[id]['tactic'] = parser.event(id)

# %%
events, related_events, freeze_frame, tactics = parser.event(match_id=match_id)
events.head()
# Out:
#                                      id  index  period        timestamp  \
# 0  794ec549-5288-4d1a-93e8-0fc6d3968784      1       1         00:00:00
# 1  3a9a2c57-b177-47ed-9447-11f081b0e388      2       1         00:00:00
# 2  1f956a2b-ece0-475b-8802-e82ed922c307      3       1         00:00:00
# 3  79b90fbb-2cfd-419b-90f4-f0e5980c47d3      4       1         00:00:00
# 4  221b0c8d-6386-4ae8-bb4a-a1dc98742312      5       1  00:00:03.417000
#
#    minute  second  possession  duration  match_id  type_id  ...  \
# 0       0       0           1  0.000000   3895302       35  ...
# 1       0       0           1  0.000000   3895302       35  ...
# 2       0       0           1  0.000000   3895302       18  ...
# 3       0       0           1  0.000000   3895302       18  ...
# 4       0       3           2  0.453249   3895302       30  ...
#
#   foul_committed_card_name  block_save_block shot_one_on_one  \
# 0                      NaN               NaN             NaN
# ...

# %%
shots = events[events['type_name'] == 'Shot']
shots.head()
# Out:
#                                        id  index  period        timestamp  \
# 435  c577e730-b9f5-44f2-9257-9e7730c23d7b    436       1  00:06:48.773000
# 479  bbc2c68d-c096-483d-abf4-32c0175a0f55    480       1  00:07:40.953000
# 596  12b5206b-9ed0-4b1e-9ec3-f2028187e09f    597       1  00:11:08.471000
# 683  b2c3d59d-3bef-4f8a-ad86-26b69940c64e    684       1  00:13:16.073000
# 847  bb53b537-1685-4019-9e8f-98f3805828eb    848       1  00:16:00.956000
#
#      minute  second  possession  duration  match_id  type_id  ...  \
# 435       6      48          13  0.052872   3895302       16  ...
# 479       7      40          14  0.217872   3895302       16  ...
# 596      11       8          22  0.445768   3895302       16  ...
# 683      13      16          26  0.085298   3895302       16  ...
# 847      16       0          33  0.402989   3895302       16  ...
#
#     foul_committed_card_name  block_save_block shot_one_on_one  \
# ...

# %%
shots.columns
# Out:
# Index(['id', 'index', 'period', 'timestamp', 'minute', 'second', 'possession',
#        'duration', 'match_id', 'type_id', 'type_name', 'possession_team_id',
#        'possession_team_name', 'play_pattern_id', 'play_pattern_name',
#        'team_id', 'team_name', 'tactics_formation', 'player_id', 'player_name',
#        'position_id', 'position_name', 'pass_recipient_id',
#        'pass_recipient_name', 'pass_length', 'pass_angle', 'pass_height_id',
#        'pass_height_name', 'end_x', 'end_y', 'body_part_id', 'body_part_name',
#        'sub_type_id', 'sub_type_name', 'x', 'y', 'under_pressure',
#        'outcome_id', 'outcome_name', 'counterpress', 'out', 'aerial_won',
#        'off_camera', 'pass_switch', 'pass_cross', 'shot_statsbomb_xg',
#        'shot_first_time', 'technique_id', 'technique_name',
#        'goalkeeper_position_id', 'goalkeeper_position_name',
#        'pass_assisted_shot_id', 'pass_shot_assist', 'end_z',
# ...

# %%
filtered_shots = shots[['aerial_won','body_part_name','shot_first_time','x','y','pass_deflected', 'block_deflection','shot_one_on_one','play_pattern_name','type_name','goalkeeper_position_name','technique_name']] #We select the usefull variables to manage our model and we omit the ones we don't think that are necessary

# %%
filtered_shots.head(15)
# Out:
#      aerial_won body_part_name shot_first_time      x     y pass_deflected  \
# 435         NaN     Right Foot            True  100.4  35.1            NaN
# 479         NaN      Left Foot            True  114.6  33.5            NaN
# 596         NaN      Left Foot            True  106.2  55.8            NaN
# 683         NaN           Head             NaN  113.9  47.4            NaN
# 847         NaN      Left Foot             NaN   89.2  42.5            NaN
# 853        True           Head             NaN  110.2  32.6            NaN
# 989         NaN     Right Foot             NaN  105.4  45.1            NaN
# 1192        NaN     Right Foot             NaN  108.0  40.0            NaN
# 1309        NaN      Left Foot            True  101.5  47.5            NaN
# 1315       True           Head             NaN  116.3  46.0            NaN
# 1318        NaN     Right Foot            True  116.3  43.3            NaN
# ...
