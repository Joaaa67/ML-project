# %% [markdown]
# https://github.com/statsbomb/open-data dataset

# %%
from mplsoccer import Sbopen
parser = Sbopen(dataframe=True)
events_df, related, freeze, tactics = parser.event(match_id=3788741)

# %%
matches = parser.match(competition_id=9, season_id=281)
matches.head()
# Out:
#    match_id match_date            kick_off  home_score  away_score  \
# 0   3895302 2024-04-14 2024-04-14 17:30:00           5           0
# 1   3895292 2024-04-06 2024-04-06 15:30:00           0           1
# 2   3895333 2024-05-05 2024-05-05 18:30:00           1           5
# 3   3895340 2024-05-12 2024-05-12 20:30:00           0           5
# 4   3895348 2024-05-18 2024-05-18 16:30:00           2           1
#
#   match_status match_status_360               last_updated  \
# 0    available        available 2024-05-10 16:57:53.017895
# 1    available        available 2024-05-12 21:04:50.061716
# 2    available        available 2024-05-14 16:23:06.325967
# 3    available        available 2024-05-14 10:09:25.875345
# 4    available        available 2024-05-20 10:11:27.857660
#
#             last_updated_360  match_week  ...  competition_stage_id  \
# 0 2024-05-10 17:03:59.613154          29  ...                     1
# 1 2024-05-12 21:08:37.897296          28  ...                     1
# 2 2024-05-14 16:32:13.483516          32  ...                     1
# 3 2024-05-14 16:46:08.459843          33  ...                     1
# 4 2024-05-20 10:33:09.140760          34  ...                     1
#
#   competition_stage_name stadium_id                    stadium_name  \
# 0         Regular Season        377                        BayArena
# 1         Regular Season        560  Stadion An der Alten Försterei
# 2         Regular Season     116458              Deutsche Bank Park
# 3         Regular Season        550             Vonovia Ruhrstadion
# 4         Regular Season        377                        BayArena
#
#   stadium_country_id  stadium_country_name referee_id         referee_name  \
# 0                 85               Germany        234          Harm Osmers
# 1                 85               Germany        235       Benjamin Brand
# 2                 85               Germany        237    Christian Dingert
# 3                 85               Germany        235       Benjamin Brand
# 4                 85               Germany        837  Matthias Jöllenbeck
#
#   referee_country_id  referee_country_name
# 0                 85               Germany
# 1                 85               Germany
# 2                 85               Germany
# 3                 85               Germany
# 4                 85               Germany
#
# [5 rows x 52 columns]

# %%
match_id = matches.iloc[0].match_id

# %%
events, related_events, freeze_frame, tactics = parser.event(match_id=match_id)
events.head()
# Out:
#                                      id  index  period        timestamp  \
# 0  794ec549-5288-4d1a-93e8-0fc6d3968784      1       1         00:00:00
# 1  3a9a2c57-b177-47ed-9447-11f081b0e388      2       1         00:00:00
# 2  1f956a2b-ece0-475b-8802-e82ed922c307      3       1         00:00:00
# 3  79b90fbb-2cfd-419b-90f4-f0e5980c47d3      4       1         00:00:00
# 4  221b0c8d-6386-4ae8-bb4a-a1dc98742312      5       1  00:00:03.417000
#
#    minute  second  possession  duration  match_id  type_id  ...  \
# 0       0       0           1  0.000000   3895302       35  ...
# 1       0       0           1  0.000000   3895302       35  ...
# 2       0       0           1  0.000000   3895302       18  ...
# 3       0       0           1  0.000000   3895302       18  ...
# 4       0       3           2  0.453249   3895302       30  ...
#
#   foul_committed_card_name  block_save_block shot_one_on_one  \
# 0                      NaN               NaN             NaN
# 1                      NaN               NaN             NaN
# 2                      NaN               NaN             NaN
# 3                      NaN               NaN             NaN
# 4                      NaN               NaN             NaN
#
#    substitution_replacement_id substitution_replacement_name  \
# 0                          NaN                           NaN
# 1                          NaN                           NaN
# 2                          NaN                           NaN
# 3                          NaN                           NaN
# 4                          NaN                           NaN
#
#    bad_behaviour_card_id bad_behaviour_card_name pass_cut_back  \
# 0                    NaN                     NaN           NaN
# 1                    NaN                     NaN           NaN
# 2                    NaN                     NaN           NaN
# 3                    NaN                     NaN           NaN
# 4                    NaN                     NaN           NaN
#
#    pass_goal_assist dribble_nutmeg
# 0               NaN            NaN
# 1               NaN            NaN
# 2               NaN            NaN
# 3               NaN            NaN
# 4               NaN            NaN
#
# [5 rows x 75 columns]

# %%
shots = events[events['type_name'] == 'Shot']
shots.head()
# Out:
#                                        id  index  period        timestamp  \
# 435  c577e730-b9f5-44f2-9257-9e7730c23d7b    436       1  00:06:48.773000
# 479  bbc2c68d-c096-483d-abf4-32c0175a0f55    480       1  00:07:40.953000
# 596  12b5206b-9ed0-4b1e-9ec3-f2028187e09f    597       1  00:11:08.471000
# 683  b2c3d59d-3bef-4f8a-ad86-26b69940c64e    684       1  00:13:16.073000
# 847  bb53b537-1685-4019-9e8f-98f3805828eb    848       1  00:16:00.956000
#
#      minute  second  possession  duration  match_id  type_id  ...  \
# 435       6      48          13  0.052872   3895302       16  ...
# 479       7      40          14  0.217872   3895302       16  ...
# 596      11       8          22  0.445768   3895302       16  ...
# 683      13      16          26  0.085298   3895302       16  ...
# 847      16       0          33  0.402989   3895302       16  ...
#
#     foul_committed_card_name  block_save_block shot_one_on_one  \
# 435                      NaN               NaN             NaN
# 479                      NaN               NaN             NaN
# 596                      NaN               NaN             NaN
# 683                      NaN               NaN             NaN
# 847                      NaN               NaN             NaN
#
#      substitution_replacement_id substitution_replacement_name  \
# 435                          NaN                           NaN
# 479                          NaN                           NaN
# 596                          NaN                           NaN
# 683                          NaN                           NaN
# 847                          NaN                           NaN
#
#      bad_behaviour_card_id bad_behaviour_card_name pass_cut_back  \
# 435                    NaN                     NaN           NaN
# 479                    NaN                     NaN           NaN
# 596                    NaN                     NaN           NaN
# 683                    NaN                     NaN           NaN
# 847                    NaN                     NaN           NaN
#
#      pass_goal_assist dribble_nutmeg
# 435               NaN            NaN
# 479               NaN            NaN
# 596               NaN            NaN
# 683               NaN            NaN
# 847               NaN            NaN
#
# [5 rows x 75 columns]
